# %%
from utils.dataset.dataset_concat import dataset_concat

# %%
threshold_dollar = 29200152 # for aprox 15 minutes
dataset_concat(path='./dataset', bar_type="dollar", threshold=threshold_dollar, output_file_path='./dataset/btc-01_2025-09-2025-dollar-15min/btc-01_2025-09-2025-dollar-15min.csv')

# %%
threshold_volume = 290 # for aprox 15 minutes
dataset_concat(path='./dataset', bar_type="volume", threshold=threshold_volume, output_file_path='./dataset/btc-01_2025-09-2025-volume-15min/btc-01_2025-09-2025-volume-15min.csv')
# Out:
#                              date_time  tick_num       open       high  \
# 0     2025-01-01 00:32:32.519130+00:00     46273   93576.00   93940.00
# 1     2025-01-01 00:57:57.067039+00:00     82520   93940.00   94330.59
# 2     2025-01-01 01:05:28.341289+00:00    109125   94320.00   94509.42
# 3     2025-01-01 01:31:56.527742+00:00    143810   94000.00   94172.00
# 4     2025-01-01 02:16:23.680412+00:00    195758   93947.67   93978.18
# ...                                ...       ...        ...        ...
# 19681 2025-09-30 20:54:56.617205+00:00  64380826  114170.43  114698.99
# 19682 2025-09-30 21:13:07.644125+00:00  64422962  114698.99  114754.87
# 19683 2025-09-30 21:39:52.695186+00:00  64483171  114524.02  114534.68
# 19684 2025-09-30 22:17:37.225629+00:00  64556360  114454.71  114454.72
# 19685 2025-09-30 23:12:57.728052+00:00  64618989  114162.78  114174.35
#
#              low      close     volume  cum_buy_volume  cum_ticks  \
# ...

# %%
threshold_tick = 45680.0 # for aprox 15 minutes
dataset_concat(path='./dataset', bar_type="tick", threshold=threshold_tick, output_file_path='./dataset/btc-01_2025-09-2025-tick-15min/btc-01_2025-09-2025-tick-15min.csv')
# Out:
#                              date_time  tick_num       open       high  \
# 0     2025-01-01 00:32:17.079847+00:00     45680   93576.00   93920.00
# 1     2025-01-01 00:59:15.685255+00:00     91360   93920.00   94509.42
# 2     2025-01-01 01:26:24.346744+00:00    137040   94444.02   94444.02
# 3     2025-01-01 02:04:20.592846+00:00    182720   93891.44   93989.37
# 4     2025-01-01 02:59:34.115586+00:00    228400   93762.99   94105.12
# ...                                ...       ...        ...        ...
# 19914 2025-09-30 21:29:09.425895+00:00  64454480  114727.04  114753.88
# 19915 2025-09-30 21:47:23.475470+00:00  64500160  114349.00  114531.97
# 19916 2025-09-30 22:08:17.786418+00:00  64545840  114303.24  114371.64
# 19917 2025-09-30 22:47:48.116000+00:00  64591520  114160.52  114202.90
# 19918 2025-09-30 23:32:47.020837+00:00  64637200  113960.90  114022.91
#
#              low      close     volume  cum_buy_volume  cum_ticks  \
# ...
